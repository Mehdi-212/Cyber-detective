# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
batman = pd.read_csv("batman.csv", delimiter='|', on_bad_lines='skip')
batman
# Out:
#                       id                                                url  \
# 0    1606817197149626372  https://twitter.com/craigcutch/status/16068171...
# 1    1600633888400965635  https://twitter.com/AHiggins1985/status/160063...
# 2    1600057935543304192  https://twitter.com/SHisislipper/status/160005...
# 3    1597584980892418049  https://twitter.com/wolfpacks117/status/159758...
# 4    1593090305200623616  https://twitter.com/NooneBladesmith/status/159...
# ..                   ...                                                ...
# 995   260601191157870592  https://twitter.com/adambakercolleg/status/260...
# 996   258337559116144641  https://twitter.com/GodDickStarman/status/2583...
# 997   242808279837835264  https://twitter.com/RellyRellRella/status/2428...
# 998   240325301387808768  https://twitter.com/oldmesamememe/status/24032...
# 999   238038832044449795  https://twitter.com/WoutdeNatris/status/238038...
#
#                           date  \
# ...

# %%
#nettoyage des données (utilisation de la librairie regex)
batman['renderedContent'] = batman['renderedContent'].str.replace(r"[A-Za-z.][0-9]+[A-Za-z%°.]", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"(\s-\s|-$)", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"[,!?%()/]", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"&\S*\s", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"&", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"+", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"#", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"$", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"£", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"%", " ")                                                  
batman['renderedContent'] = batman['renderedContent'].str.replace(r"@", " ")
batman['renderedContent'] = batman['renderedContent'].str.replace(r"-", " ")

batman
# Out:
#                       id                                                url  \
# 0    1606817197149626372  https://twitter.com/craigcutch/status/16068171...
# 1    1600633888400965635  https://twitter.com/AHiggins1985/status/160063...
# 2    1600057935543304192  https://twitter.com/SHisislipper/status/160005...
# 3    1597584980892418049  https://twitter.com/wolfpacks117/status/159758...
# 4    1593090305200623616  https://twitter.com/NooneBladesmith/status/159...
# ..                   ...                                                ...
# 995   260601191157870592  https://twitter.com/adambakercolleg/status/260...
# 996   258337559116144641  https://twitter.com/GodDickStarman/status/2583...
# 997   242808279837835264  https://twitter.com/RellyRellRella/status/2428...
# 998   240325301387808768  https://twitter.com/oldmesamememe/status/24032...
# 999   238038832044449795  https://twitter.com/WoutdeNatris/status/238038...
#
#                           date  \
# ...

# %%
text = " ".join(i for i in batman['renderedContent'])
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["drink", "now", "wine", "flavor", "flavors","https","t","co"])

# Generate a word cloud image
wordcloud = WordCloud(collocations = False, stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# !pip install nltk

# %%
def get_ngrams(text, ngram_from=2, ngram_to=2, n=None, max_features=20000):
    
    vec = CountVectorizer(ngram_range = (ngram_from, ngram_to), 
                          max_features = max_features, 
                          stop_words='english').fit(text)
    bag_of_words = vec.transform(text)
    sum_words = bag_of_words.sum(axis = 0) 
    words_freq = [(word, sum_words[0, i]) for word, i in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
   
    return words_freq[:n]

# %%
bigrams = get_ngrams(batman['renderedContent'], ngram_from=2, ngram_to=2,n=6)
bigrams_df = pd.DataFrame(bigrams)
bigrams_df.columns=["Bigram", "Frequency"]
bigrams_df.head()
# Out:
#           Bigram  Frequency
# 0     dark night        699
# 1  night returns        522
# 2     comic book        476
# 3    batman dark        374
# 4    dark knight        352

# %%
trigrams = get_ngrams(batman['renderedContent'], ngram_from=3, ngram_to=3, n=15)
trigrams_df = pd.DataFrame(trigrams)
trigrams_df.columns=["Trigram", "Frequency"]
trigrams_df.head()
# Out:
#                  Trigram  Frequency
# 0     dark night returns        522
# 1    dark knight returns        276
# 2      batman dark night        274
# 3     batman dark knight        100
# 4  knight returns batman         75

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# Créez un objet TextBlob à partir du texte que vous souhaitez analyser
text = batman['renderedContent']
blob = TextBlob(str(text))

# Utilisez la méthode `sentiment` pour obtenir un score de polarité et de subjectivité
possitif = blob.sentiment.polarity
negatif = blob.sentiment.subjectivity

print(f"Possitif: {possitif}")
print(f"Négatif: {negatif}")
# Out:
# Possitif: -0.03125
# Négatif: 0.5
