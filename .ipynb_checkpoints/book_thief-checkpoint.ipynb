# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
war = pd.read_csv("the_art_of_war.csv", delimiter='|', on_bad_lines='skip')
war.columns= ['tweet']
war
# Out:
#                                                   tweet
# 0     0,"If you know the enemy &amp; know yourself, ...
# 1                                                 ;;;;;
# 2                                 -The Art of War";;;;;
# 3     1,"Today's Italian American MLB player is Art ...
# 4     2,"@Cernovich @rramom59 You are such a drama q...
# ...                                                 ...
# 2616  997,"Know yourself and you will win all battle...
# 2617                                              ;;;;;
# 2618                     —Sun Tzu, The Art of War";;;;;
# 2619                998,@Peterman43 The art of war;;;;;
# 2620  999,"@GUUZSMAAN @mojomoby @onerob0t @TritzChri...
#
# [2621 rows x 1 columns]

# %%
#nettoyage des données (utilisation de la librairie regex)
war['tweet'] = war['tweet'].str.replace(r"[A-Za-z.][0-9]+[A-Za-z%°.]", " ")
war['tweet'] = war['tweet'].str.replace(r"(\s-\s|-$)", " ")
war['tweet'] = war['tweet'].str.replace(r"[,!?%()/]", " ")
war['tweet'] = war['tweet'].str.replace(r"&\S*\s", " ")
war['tweet'] = war['tweet'].str.replace(r"&", " ")
war['tweet'] = war['tweet'].str.replace(r"+", " ")
war['tweet'] = war['tweet'].str.replace(r"#", " ")
war['tweet'] = war['tweet'].str.replace(r"$", " ")
war['tweet'] = war['tweet'].str.replace(r"£", " ")
war['tweet'] = war['tweet'].str.replace(r"%", " ")                                                  
war['tweet'] = war['tweet'].str.replace(r"@", " ")
war['tweet'] = war['tweet'].str.replace(r"-", " ")
war['tweet'] = war['tweet'].str.replace(r";", " ")

war
# Out:
#                                                   tweet
# 0     0 "If you know the enemy  know yourself  you n...
# 1
# 2                                  The Art of War"
# 3     1 "Today's Italian American MLB player is Art ...
# 4     2 " Cernovich  rramom59 You are such a drama q...
# ...                                                 ...
# 2616  997 "Know yourself and you will win all battle...
# 2617
# 2618                     —Sun Tzu  The Art of War"
# 2619                998  Peterman43 The art of war
# 2620  999 " GUUZSMAAN  mojomoby  onero   TritzChrist...
#
# [2621 rows x 1 columns]

# %%
text = " ".join(i for i in war['tweet'])
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["drink", "now", "wine", "flavor", "flavors","https","t","co"])

# Generate a word cloud image
wordcloud = WordCloud(collocations = False, stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# !pip install nltk

# %%
def get_ngrams(text, ngram_from=2, ngram_to=2, n=None, max_features=20000):
    
    vec = CountVectorizer(ngram_range = (ngram_from, ngram_to), 
                          max_features = max_features, 
                          stop_words='english').fit(text)
    bag_of_words = vec.transform(text)
    sum_words = bag_of_words.sum(axis = 0) 
    words_freq = [(word, sum_words[0, i]) for word, i in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
   
    return words_freq[:n]

# %%
bigrams = get_ngrams(war['tweet'], ngram_from=2, ngram_to=2,n=6)
bigrams_df = pd.DataFrame(bigrams)
bigrams_df.columns=["Bigram", "Frequency"]
bigrams_df.head()
# Out:
#         Bigram  Frequency
# 0      art war        529
# 1      sun tzu        177
# 2      tzu art         97
# 3    war https         55
# 4  eng england         51

# %%
trigrams = get_ngrams(war['tweet'], ngram_from=3, ngram_to=3, n=15)
trigrams_df = pd.DataFrame(trigrams)
trigrams_df.columns=["Trigram", "Frequency"]
trigrams_df.head()
# Out:
#                  Trigram  Frequency
# 0            sun tzu art         96
# 1            tzu art war         96
# 2         https aful fvl         49
# 3          art war https         46
# 4  footballs coming home         36

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# Créez un objet TextBlob à partir du texte que vous souhaitez analyser
text = batman['renderedContent']
blob = TextBlob(str(text))

# Utilisez la méthode `sentiment` pour obtenir un score de polarité et de subjectivité
possitif = blob.sentiment.polarity
negatif = blob.sentiment.subjectivity

print(f"Possitif: {possitif}")
print(f"Négatif: {negatif}")
# Out:
# Possitif: -0.03125
# Négatif: 0.5
