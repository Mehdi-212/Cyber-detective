# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in c:\users\utilisateur\anaconda3\lib\site-packages (from pandasql) (1.21.5)
# Requirement already satisfied: pandas in c:\users\utilisateur\anaconda3\lib\site-packages (from pandasql) (1.4.2)
# Requirement already satisfied: sqlalchemy in c:\users\utilisateur\anaconda3\lib\site-packages (from pandasql) (1.4.32)
# Requirement already satisfied: pytz>=2020.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from sqlalchemy->pandasql) (1.1.1)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py): started
#   Building wheel for pandasql (setup.py): finished with status 'done'
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=f034b972a176be14e4c1b29783d1252e1ede49a2dd84bebf06c5673a0d8021d9
#   Stored in directory: c:\users\utilisateur\appdata\local\pip\cache\wheels\63\e8\ec\75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
import pyodbc
import pandas as pd
from pandasql import sqldf

# %%
df_books = pd.read_csv('books.csv')

books = df_books[['index', 'titre', 'prix', 'etoile', 'dispo', 'link']]
query = "SELECT * FROM books"
books = sqldf(query, globals())
books
# Out:
#      index                                              titre   prix  etoile  \
# 0        0                               A Light in the Attic  51.77       3
# 1        1                                 Tipping the Velvet  53.74       1
# 2        2                                         Soumission  50.10       1
# 3        3                                      Sharp Objects  47.82       4
# 4        4              Sapiens: A Brief History of Humankind  54.23       5
# ..     ...                                                ...    ...     ...
# 995    995  Alice in Wonderland (Alice's Adventures in Won...  55.53       1
# 996    996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06       4
# 997    997  A Spy's Devotion (The Regency Spies of London #1)  16.97       5
# 998    998                1st to Die (Women's Murder Club #1)  53.98       1
# 999    999                 1,000 Places to See Before You Die  26.08       5
#
#         dispo                                               link
# 0    In stock  https://books.toscrape.com/catalogue/a-light-i...
# 1    In stock  https://books.toscrape.com/catalogue/tipping-t...
# 2    In stock  https://books.toscrape.com/catalogue/soumissio...
# 3    In stock  https://books.toscrape.com/catalogue/sharp-obj...
# 4    In stock  https://books.toscrape.com/catalogue/sapiens-a...
# ..        ...                                                ...
# 995  In stock  https://books.toscrape.com/catalogue/alice-in-...
# 996  In stock  https://books.toscrape.com/catalogue/ajin-demi...
# 997  In stock  https://books.toscrape.com/catalogue/a-spys-de...
# 998  In stock  https://books.toscrape.com/catalogue/1st-to-di...
# 999  In stock  https://books.toscrape.com/catalogue/1000-plac...
#
# [1000 rows x 6 columns]

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=UTILISA-REVMD1C\SQLEXPRESS;'
                      'Database=books;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
sql = "INSERT INTO book(id, titre, prix, etoile, dispo, link) VALUES(?,?,?,?,?,?)"
for i,row in books.iterrows():
    cursor.execute(sql, tuple(row))    
    conn.commit()
